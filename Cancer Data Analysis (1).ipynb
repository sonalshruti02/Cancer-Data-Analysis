# %%
# !pip install seaborn
# Out:
# ...
# [notice] A new release of pip is available: 24.3.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings("ignore")

# %%
data = pd.read_csv("C:\\Users\\hp\\OneDrive\\Desktop\\Portfoliod Project X\\global_cancer_patients_2015_2024.csv")

# %%
data
# Out:
#       Patient_ID  Age  Gender Country_Region  Year  Genetic_Risk  \
# 0      PT0000000   71    Male             UK  2021           6.4
# 1      PT0000001   34    Male          China  2021           1.3
# 2      PT0000002   80    Male       Pakistan  2023           7.4
# 3      PT0000003   40    Male             UK  2015           1.7
# 4      PT0000004   43  Female         Brazil  2017           5.1
# ...          ...  ...     ...            ...   ...           ...
# 49995  PT0049995   80    Male       Pakistan  2023           2.3
# 49996  PT0049996   40  Female            USA  2018           6.4
# 49997  PT0049997   74    Male       Pakistan  2015           6.2
# 49998  PT0049998   21    Male         Brazil  2018           4.0
# 49999  PT0049999   22    Male       Pakistan  2023           5.1
#
#        Air_Pollution  Alcohol_Use  Smoking  Obesity_Level Cancer_Type  \
# 0                2.8          9.5      0.9            8.7        Lung
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Patient_ID             50000 non-null  object
#  1   Age                    50000 non-null  int64
#  2   Gender                 50000 non-null  object
#  3   Country_Region         50000 non-null  object
#  4   Year                   50000 non-null  int64
#  5   Genetic_Risk           50000 non-null  float64
#  6   Air_Pollution          50000 non-null  float64
#  7   Alcohol_Use            50000 non-null  float64
#  8   Smoking                50000 non-null  float64
#  9   Obesity_Level          50000 non-null  float64
#  10  Cancer_Type            50000 non-null  object
#  11  Cancer_Stage           50000 non-null  object
#  12  Treatment_Cost_USD     50000 non-null  float64
#  13  Survival_Years         50000 non-null  float64
# ...

# %%
data.isnull().sum()
# Out:
# Patient_ID               0
# Age                      0
# Gender                   0
# Country_Region           0
# Year                     0
# Genetic_Risk             0
# Air_Pollution            0
# Alcohol_Use              0
# Smoking                  0
# Obesity_Level            0
# Cancer_Type              0
# Cancer_Stage             0
# Treatment_Cost_USD       0
# Survival_Years           0
# Target_Severity_Score    0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # Descriptive Analysis

# %%
data["Age"]
# Out:
# 0        71
# 1        34
# 2        80
# 3        40
# 4        43
#          ..
# 49995    80
# 49996    40
# 49997    74
# 49998    21
# 49999    22
# Name: Age, Length: 50000, dtype: int64

# %%
#Plotting for age column
plt.figure(figsize=(10,4))

plt.subplot(1,2,1)
sns.kdeplot(data["Age"],fill = True,color = "lightgreen")
plt.title("KDE plot for Age")


plt.subplot(1,2,2)
sns.histplot(data["Age"],bins = 30, kde = False, color="cyan")
plt.title("Histogram plot for Age")

plt.tight_layout()
plt.show()

# %%
data["Age"].describe()
# Out:
# count    50000.000000
# mean        54.421540
# std         20.224451
# min         20.000000
# 25%         37.000000
# 50%         54.000000
# 75%         72.000000
# max         89.000000
# Name: Age, dtype: float64

# %% [raw]
# * INFERENCE:
#
# Range: 20 to 89 years
# Mean Avg: 54.42 years
# Standard Deviation: 20.22
# Interquartile Range(IQR): 37(Q1) to 72(Q2)
# This suggests a broad representataion of both yound and elderly patients in the dataset , which supports age-based comparative analysis.

# %%
# Gender Column
data["Gender"].value_counts()

sns.barplot(x=data["Gender"].value_counts().index,
            y=data["Gender"].value_counts().values,
            palette=["blue", "pink","green"]
           )
for i , v in enumerate(data["Gender"].value_counts()):
    plt.text(i,v, str(v) , ha="center" , va="bottom")

plt.title("Gender count")
plt.xlabel("Gender")
plt.ylabel("Count")
plt.show()

# %%
data["Gender"].value_counts()
# Out:
# Gender
# Male      16796
# Female    16709
# Other     16495
# Name: count, dtype: int64

# %% [raw]
# * INFERENCE
#
# the dataset contain three gender categories(Male , Female , other) with the most common being Male(16,796 records).
# Gender distribution is sufficient for evaluating gender-specific survival trends and severity outcomes.

# %%
# Countries column

country_counts = data["Country_Region"].value_counts()
plt.figure(figsize=(5,5))
plt.pie(x=country_counts.values,
        labels =country_counts.index,
        autopct = '%1.1f%%'
       )

plt.title("Country/Region Distribution")
plt.show()

# %%
country_counts
# Out:
# Country_Region
# Australia    5092
# UK           5060
# USA          5060
# India        5040
# Germany      5024
# Russia       5017
# Brazil       5004
# Pakistan     4926
# China        4913
# Canada       4864
# Name: count, dtype: int64

# %% [raw]
# * INFERENCE
#
# Patient come from 10 different countries , with Australia being the most represented (5,092 patients).Number of data points for each country is almost same.
# This diversity enables cross-country comparison of cancer outcomes and treated economic.

# %%
# cancer type
data["Cancer_Type"].value_counts()

sns.barplot(x=data["Cancer_Type"].value_counts().index,
            y=data["Cancer_Type"].value_counts().values)
for i , v in enumerate(data["Cancer_Type"].value_counts()):
    plt.text(i,v, str(v), ha="center" , va="bottom")

plt.title("Cancer type count")
plt.xlabel("Cancer type")
plt.ylable("Count")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 11
#       9 plt.title("Cancer type count")
#      10 plt.xlabel("Cancer type")
# ---> 11 plt.ylable("Count")
#      12 plt.show()
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'ylable'

# %% [raw]
# *INFERENCE
#
# We have in total 9 types of cancer , with each cancer having approx same number of data poitns under the lable , most common type of cancers are colon cancer followed by Prostrate cancer

# %%
# Cancer stage
data["Cancer_Stage"].value_counts()

sns.barplot(x=data["Cancer_Stage"].value_counts().index,
            y=data["Cancer_Stage"].value_counts().values)
for i , v in enumerate(data["Cancer_Stage"].value_counts()):
    plt.text(i,v, str(v), ha="center" , va="bottom")

plt.title("Cancer Stage count")
plt.xlabel("Cancer Satge")
plt.ylable("Count")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[16], line 11
#       9 plt.title("Cancer Stage count")
#      10 plt.xlabel("Cancer Satge")
# ---> 11 plt.ylable("Count")
#      12 plt.show()
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'ylable'

# %% [raw]
# * INFERENCE
#
# Cancer stage have 5 stages with value ranging from 0 to 4 , with stage 2 the most common one , and each stage have almost same number of data points under its label.

# %%
#  Plotting for Treatment_Cost_USD
data["Treatment_Cost_USD"].value_counts()
plt.figure(figsize=(10,4))

plt.subplot(1,2,1)
sns.kdeplot(data["Treatment_Cost_USD"],fill = True,color = "lightgreen")
plt.title("KDE plot for Treatment_Cost_USD")


plt.subplot(1,2,2)
sns.histplot(data["Treatment_Cost_USD"],bins = 30, kde = False, color="cyan")
plt.title("Histogram plot for Treatment_Cost_USD")

plt.tight_layout()
plt.show()

# %%
data["Treatment_Cost_USD"].describe()
# Out:
# count    50000.000000
# mean     52467.298239
# std      27363.229379
# min       5000.050000
# 25%      28686.225000
# 50%      52474.310000
# 75%      76232.720000
# max      99999.840000
# Name: Treatment_Cost_USD, dtype: float64

# %% [raw]
# *INFERENCE
#
# Treatment_Cost_USD have no skewness , and there are almost same number of data points under each bins as observedby histogram

# %%
# ANALyZING THE RISK FACTORS
column_of_interest = ['Genetic_Risk','Air_Pollution', 'Alcohol_Use', 'Smoking', 'Obesity_Level']

summary = data[column_of_interest].agg(["mean","std", "min","max"])
summary
# Out:
#       Genetic_Risk  Air_Pollution  Alcohol_Use    Smoking  Obesity_Level
# mean      5.001698       5.010126     5.010880   4.989826       4.991176
# std       2.885773       2.888399     2.888769   2.881579       2.894504
# min       0.000000       0.000000     0.000000   0.000000       0.000000
# max      10.000000      10.000000    10.000000  10.000000      10.000000

# %% [raw]
# * INFERENCE
#
# These varibales have nearly identical means and standard deviations , indicating they were likely designed on the same standardized scale . They are essential in studying interaction effects(e.g., genetic risk x smoking) on survival.

# %% [markdown]
# # Determine the relationship between risk factors and cancer severity

# %%
from scipy.stats import linregress

risk_factors = ['Genetic_Risk','Air_Pollution', 'Alcohol_Use', 'Smoking', 'Obesity_Level']
titles = ['Genetic Risk','Air Pollution', 'Alcohol Use', 'Smoking', 'Obesity Level']
colors = ["blue", "green" , "orange", "red", "purple"]

#fig , axes = plt.subplots(2,3, figsize=(20,10))
#axes = axes.flatten()
plt.figure(figsize=(20,12))
for i , (factor , title, color)in enumerate(zip(risk_factors , titles , colors),1):
   plt.subplot(2,3,i)
    
x=data[factor]
y=data["Target_Severity_Score"]
slope, intercept, r_value, p_value, std_err = linregress(x,y)
r_squared=r_value**2

sns.lineplot(x=factor, y="Target_Severity_Score", data=data , color=color)
plt.plot(x,x*slope+intercept, color = "black", linewidth=2 , label="Regression Line")
plt.title(f"{title} vs Severity Score\n R2 = {r_squared},Slope = {slope}")
plt.xlabel(factor)
plt.ylabel("Target_Severity_Score")
plt.legend()

#line = y = mx+c

plt.tight_layout()
plt.show()

# %% [raw]
# *Key Takeaways:
# Weak Linear Relationships:
# The R2 svalues for all risk factors are relatively low, ranging from 0.06 to 0.23.This indicates that while teher is some relation between these risk factors and the Target_Severity_Score , it is weak.These factors alone donot explain much of the variation in the target variable.
#
#
# Positive Trends:
# All the slope values are positive , suggesting that as each risk factors increases , The Target_Severity_Score tends to also increase. However because the R2 values are low , this increase is not strongly consistent across all data points.
#
#
# Other Influences:
# Th low R2 values imply that other , unmeasured factors are likely contributing to the variations in Targte_Severity_Score. The risk factors you examined are only weakly correlated with the target and are not reliable predictors on their own.
#
#
# Next Steps:
# Given the weak explanatory power of thees individual factors , it might be usefull to explore other variables or more complex models that could account for more of the variations in the Target_Severity_Score. This could include interactions between risk factors , adding new features , or applying more sophisticated regression techniques.

# %% [markdown]
# # Analyze the proportion of early-stage diagnoses by cancer type

# %%
data["Cancer_Type"].unique()
# Out:
# array(['Lung', 'Leukemia', 'Breast', 'Colon', 'Skin', 'Cervical',
#        'Prostate', 'Liver'], dtype=object)

# %%
stage_count = data[data["Cancer_Type"]=="Lung"]["Cancer_Stage"].value_counts()
early_stage_sum= stage_count.get("Stage 0",0)+ stage_count.get("Stage I",0)
total_sum =stage_count.sum()
proportion=(early_stage_sum /total_sum )*100
print(f"porportion of lungs cancer diagnosed at stage 0 and stage 1: {proportion}")
# Out:
# porportion of lungs cancer diagnosed at stage 0 and stage 1: 38.43156356551388

# %%
stage_count = data[data["Cancer_Type"]=="Leukemia"]["Cancer_Stage"].value_counts()
early_stage_sum= stage_count.get("Stage 0",0)+ stage_count.get("Stage I",0)
total_sum =stage_count.sum()
proportion=(early_stage_sum /total_sum )*100
print(f"porportion of Leukemia cancer diagnosed at stage 0 and stage 1: {proportion}")
# Out:
# porportion of Leukemia cancer diagnosed at stage 0 and stage 1: 39.53080114905841

# %%
stage_count = data[data["Cancer_Type"]=="Breast"]["Cancer_Stage"].value_counts()
early_stage_sum= stage_count.get("Stage 0",0)+ stage_count.get("Stage I",0)
total_sum =stage_count.sum()
proportion=(early_stage_sum /total_sum )*100
print(f"porportion of Breast cancer diagnosed at stage 0 and stage 1: {proportion}")
# Out:
# porportion of Breast cancer diagnosed at stage 0 and stage 1: 39.47325900791727

# %%
stage_count = data[data["Cancer_Type"]=="Colon"]["Cancer_Stage"].value_counts()
early_stage_sum= stage_count.get("Stage 0",0)+ stage_count.get("Stage I",0)
total_sum =stage_count.sum()
proportion=(early_stage_sum /total_sum )*100
print(f"porportion of Colon cancer diagnosed at stage 0 and stage 1: {proportion}")
# Out:
# porportion of Colon cancer diagnosed at stage 0 and stage 1: 40.41718946047679

# %%
stage_count = data[data["Cancer_Type"]=="Skin"]["Cancer_Stage"].value_counts()
early_stage_sum= stage_count.get("Stage 0",0)+ stage_count.get("Stage I",0)
total_sum =stage_count.sum()
proportion=(early_stage_sum /total_sum )*100
print(f"porportion of Skin cancer diagnosed at stage 0 and stage 1: {proportion}")
# Out:
# porportion of Skin cancer diagnosed at stage 0 and stage 1: 40.41084898090194

# %%
stage_count = data[data["Cancer_Type"]=="Cervical"]["Cancer_Stage"].value_counts()
early_stage_sum= stage_count.get("Stage 0",0)+ stage_count.get("Stage I",0)
total_sum =stage_count.sum()
proportion=(early_stage_sum /total_sum )*100
print(f"porportion of Cervical cancer diagnosed at stage 0 and stage 1: {proportion}")
# Out:
# porportion of Cervical cancer diagnosed at stage 0 and stage 1: 39.85856637737062

# %%
stage_count = data[data["Cancer_Type"]=="Prostate"]["Cancer_Stage"].value_counts()
early_stage_sum= stage_count.get("Stage 0",0)+ stage_count.get("Stage I",0)
total_sum =stage_count.sum()
proportion=(early_stage_sum /total_sum )*100
print(f"porportion of Prostate cancer diagnosed at stage 0 and stage 1: {proportion}")
# Out:
# porportion of Prostate cancer diagnosed at stage 0 and stage 1: 40.187064045656314

# %%
stage_count = data[data["Cancer_Type"]=="Liver"]["Cancer_Stage"].value_counts()
early_stage_sum= stage_count.get("Stage 0",0)+ stage_count.get("Stage I",0)
total_sum =stage_count.sum()
proportion=(early_stage_sum /total_sum )*100
print(f"porportion of Liver cancer diagnosed at stage 0 and stage 1: {proportion}")
# Out:
# porportion of Liver cancer diagnosed at stage 0 and stage 1: 40.614498319731155

# %%
stage_count.sum()

# %% [raw]
# * INFERENCE
# The analysis demonstrates that early stage diagnosis for various cancer types is relatively widespread , with most cancers having an early diagnosis rate between 38.43% to 40.61%. Liver cancer shows the highest proportion , while Lungs cancer shows the lowest. These findings suggsest that while screening and diagnosis methods are effective , improvements can still be made , particularly in lung cancer detection.
#
#
# Futher research into screening strategies , early intervention , and the use of advanced diagnosis technologies could help increase the proportion of early-stage diagnosis , ultimately leading to better survival rates and outcomes for cancer patients. The relatively small variations across the cancer types indicates that , in general , healthcare systems may need to focus on enhancing early detection uniformly, with targeted efforts to address specific gaps in detection , particularly for cancers like Lung cancer.

# %% [markdown]
# # Identify key predictors(risk factors) of cancer severity and survival years.

# %%
#we will use correlation analysis and feature selection using random forest
# In correlation we will find out pearson(linaer) and spearman(monotonic correlation) correlation and this will tells us how individually each factor is effecting the output
# random forest will tell us which factors is explaning the variation of our output.
# And col which will be common from both Correlation and feature selection will be our top predictors.

# %%
features = ["Age",'Genetic_Risk','Air_Pollution', 'Alcohol_Use', 'Smoking', 'Obesity_Level']

targets = ["Survival_Years" , "Target_Severity_Score"]

#calculate correlations
pearson_corr = data[features+targets].corr(method="pearson")
spearman_corr = data[features+targets].corr(method="spearman")

#slice out only the realtionship with target variables
pearson_results = pearson_corr[targets]
spearman_results = spearman_corr[targets]

#combine both
correlation_df = pd.concat([pearson_results,spearman_results], axis=1 , keys=["Pearson","Spearman"])
correlation_df
# Out:
#                              Pearson                             Spearman  \
#                       Survival_Years Target_Severity_Score Survival_Years
# Age                        -0.000147             -0.001481      -0.000149
# Genetic_Risk                0.001708              0.478700       0.001684
# Air_Pollution               0.000893              0.366963       0.000841
# Alcohol_Use                -0.000527              0.363250      -0.000543
# Smoking                     0.001371              0.484420       0.001372
# Obesity_Level               0.009771              0.251366       0.009780
# Survival_Years              1.000000              0.004161       1.000000
# Target_Severity_Score       0.004161              1.000000       0.003431
#
#
#                       Target_Severity_Score
# Age                               -0.002076
# Genetic_Risk                       0.472193
# Air_Pollution                      0.357528
# Alcohol_Use                        0.354694
# ...

# %% [markdown]
# ![Features.png](attachment:98ec29a7-06e0-4193-bf6f-dd2523597829.png)

# %% [markdown]
# ![All features.png](attachment:dcabea67-cc83-4355-8f03-96b4a10c3d78.png)

# %%
# Random Forest for target severity score
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import r2_score


#converting categorical columns to  numerical columns
categorical_cols = ["Gender", "Country_Region" , "Cancer_Type", "Cancer_Stage"] 
for col in categorical_cols:
    le = LabelEncoder()
    data[col]=le.fit_transform(data[col])


#Preparing features and input
x= data.drop(columns=["Patient_ID","Survival_Years", "Target_Severity_Score","Treatment_Cost_USD"])
y_severity=data["Target_Severity_Score"]


#Train test split
x_train_s,x_test_s,y_train_s, y_test_s =train_test_split(x,y_severity,test_size = 0.2,random_state=40)


#Train the model
model = RandomForestRegressor(n_estimators=200,max_depth= None , min_samples_split = 2, min_samples_leaf = 1, random_state = 40)
model.fit(x_train_s , y_train_s)

#evaluate the model
train_r2_severity = r2_score(y_train_s , model.predict(x_train_s))
test_r2_severity = r2_score(y_test_s , model.predict(x_test_s))

# %%
print(train_r2_severity)
print(test_r2_severity)
# Out:
# 0.9689503792116058
# 0.7752278237418935

# %%
feature_importance_severity = pd.Series(model.feature_importances_, index=x.columns,).sort_values(ascending=True)


#plotting of important features
plt.figure(figsize=(10,6))
feature_importance_severity.plot(kind="bar",color="skyblue")
plt.title("Feature importance for Target Severity Score for (Random Forest)")
plt.xlable("Features")
plt.ylable("Imporatnce Score")
plt.xticks(rotation=40)
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[33], line 8
#       6 feature_importance_severity.plot(kind="bar",color="skyblue")
#       7 plt.title("Feature importance for Target Severity Score for (Random Forest)")
# ----> 8 plt.xlable("Features")
#       9 plt.ylable("Imporatnce Score")
#      10 plt.xticks(rotation=40)
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'xlable'

# %% [raw]
# *INFERENCE
# Feature Importance Interpretation
# Smoking 0.25 Most important predictor of severity score , The more a patient smokes , the higher their severity tends to be .
# Genetic_Risk 0.24 Strong genetic predisposition is nearly as important as smoking.
# Treatmnet_Cost_USD  0.21 Higher treatment costs are associate with more severe conditions.
# Alcohol_Use 0.17 Alcohol also plays significant role.
# Air_Pollution 0.18 Environmental Factor-patients in more polluted areas have worse severity scores.
# Obesity_Level 0.087 Has an effect , but much smaller.
# Age & Gender < 0.01 Very leow importance , thses don't explain much variation in severity score.
#
#
# E.g., Smoking , Genetic Risk , Air pollution are major infulencers . This tells you where interventions might reduce severity.

# %%
# Random Forest for target severity score
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import r2_score


#converting categorical columns to  numerical columns
categorical_cols = ["Gender", "Country_Region" , "Cancer_Type", "Cancer_Stage"] 
for col in categorical_cols:
    le = LabelEncoder()
    data[col]=le.fit_transform(data[col])


#Preparing features and input
x= data.drop(columns=["Patient_ID","Survival_Years", "Target_Severity_Score","Treatment_Cost_USD"])
y_severity=data["Survival_Years"]


#Train test split
x_train_s,x_test_s,y_train_s, y_test_s =train_test_split(x,y_severity,test_size = 0.2,random_state=40)

param_grid = {
    'n_estimators':[100,200],
    'max_depth':[5,10,None],
    'min_samples_split':[2,5],
    'min_samples_leaf':[1,2]

}


#Train the model
model = RandomForestRegressor(random_state = 40)
GSC=GridSearchCV(model, param_grid , cv=3 , scoring ="r2" , n_jobs=-1)
GSC.fit(x_train_s , y_train_s)

best_rf_severity = GSC.best_estimator_

#evaluate the model
train_r2_severity = r2_score(y_train_s , best_rf_severity.predict(x_train_s))
test_r2_severity = r2_score(y_test_s , best_rf_severity.predict(x_test_s))

# %%
print(train_r2_severity)
print(test_r2_severity)
# Out:
# 0.008998065861791305
# -0.0003487352301705382

# %%
import seaborn as sns
sns.histplot(data["Survival_Years"], kde=True)
# Out:
# <Axes: xlabel='Survival_Years', ylabel='Count'>

# %%
data.corr(numeric_only=True)["Survival_Years"].sort_values(ascending=True)
# Out:
# Gender                  -0.007121
# Cancer_Stage            -0.003014
# Cancer_Type             -0.001717
# Alcohol_Use             -0.000527
# Treatment_Cost_USD      -0.000429
# Age                     -0.000147
# Year                     0.000018
# Air_Pollution            0.000893
# Smoking                  0.001371
# Genetic_Risk             0.001708
# Target_Severity_Score    0.004161
# Country_Region           0.005121
# Obesity_Level            0.009771
# Survival_Years           1.000000
# Name: Survival_Years, dtype: float64

# %% [raw]
# "The information in your columns does not help the model figure out how long someoen will survive."

# %% [markdown]
# # Explore the economic burden of cancer treatment across different demographics and countries

# %%
data = pd.read_csv("C:\\Users\\hp\\OneDrive\\Desktop\\Portfoliod Project X\\global_cancer_patients_2015_2024.csv")
data
# Out:
#       Patient_ID  Age  Gender Country_Region  Year  Genetic_Risk  \
# 0      PT0000000   71    Male             UK  2021           6.4
# 1      PT0000001   34    Male          China  2021           1.3
# 2      PT0000002   80    Male       Pakistan  2023           7.4
# 3      PT0000003   40    Male             UK  2015           1.7
# 4      PT0000004   43  Female         Brazil  2017           5.1
# ...          ...  ...     ...            ...   ...           ...
# 49995  PT0049995   80    Male       Pakistan  2023           2.3
# 49996  PT0049996   40  Female            USA  2018           6.4
# 49997  PT0049997   74    Male       Pakistan  2015           6.2
# 49998  PT0049998   21    Male         Brazil  2018           4.0
# 49999  PT0049999   22    Male       Pakistan  2023           5.1
#
#        Air_Pollution  Alcohol_Use  Smoking  Obesity_Level Cancer_Type  \
# 0                2.8          9.5      0.9            8.7        Lung
# ...

# %%
country_gender_cost=data.groupby(["Country_Region","Gender"])["Treatment_Cost_USD"].mean().reset_index()

# %%
data["Age_Group"]=pd.cut(data["Age"],bins=[0,30,45,60,75,100],labels=["0-30","31-45","46-60","61-75","76+"])

# %%
country_age_cost=data.groupby(["Country_Region","Age_Group","Gender"])["Treatment_Cost_USD"].mean().reset_index()
plt.figure(figsize=(10,6))
sns.barplot(data=country_age_cost,x="Country_Region",y="Treatment_Cost_USD",hue="Gender")
plt.title("Average cancer treatment cost by country and gender")
plt.show()

# %%
country_age_cost=data.groupby(["Country_Region","Age_Group"])["Treatment_Cost_USD"].mean().reset_index()

# %%
heatmap_data=country_age_cost.pivot(index="Age_Group",columns="Country_Region",values="Treatment_Cost_USD")

# %%
plt.figure(figsize=(10,6))
sns.heatmap(heatmap_data,annot=True,fmt=".0f")
plt.title("Average Treatment cost by Age Group and Country")
plt.show()

# %% [raw]
# * Inference
# Grographic Disparities in Economic Burden
# Cancer treatment costs are significantally higher in developed nations such as USA,Australia and China, revealing the heavy financial load in advanced healthcare systems.Meanwhile, countries like India and Pakistan exhibit comparatively lower costs , likely due to lower healthcare pricing structures or limited access to advanced treatment.This highlights a clear global inequailty in healthcare affordability that can intensify  financial strain depending on a patient's country of residence.
#
# Gender-Based Cost Patterns Are Uniform
# Across all countries , gender-based differences in average treatment costs are minimal , suggesting no major gender bias in pricing or access to cancer care. This uniformity may reflect standardization in treatment protocols or eqitable healthcare policies, but it also points to the fact that the financial impact of cancer is universal accross genders.
#
# Age-Related Escalation in Treatment Costs
# Treatment costs tend to rise with age , particularly for those aged 61 and above. This trend is especially evident in countries like Australia and the USA , where older aged groups face sharply higher costs. The increased financial burden in thees groups could be due to more intensive care needs, multiple comorbidities , or prolonged treatments. This pattern underlines the vulnerability of elderly populations and the pressing need for targeted support for senior citizens.
#
# Role of Healthcare Systems in Cost Variations
# Countries with robust public healthcare system-such as Canada , germany and the UK show relatively stabel treatment costs acorss all age groups, reflecting the benefits of healthcare subsidies or coverage. This consistency reinforces the importance of government intervention and universal healthcare in mitigating financial disparities in cancer treatments.

# %% [markdown]
# # Assess whether higher treatment cost is associated with longer survival

# %% [raw]
# Null Hypothesis (H0) :- There is no correlation between treatment cost and survival years.
# Alternative Hypothesis (H1) :- There is a correlation(positive or negative) between  treatment cost and survival years.

# %%
from scipy.stats import pearsonr , spearmanr
x = data["Treatment_Cost_USD"]
y=data["Survival_Years"]

#performing perason correlation test
pearson_corr , pearson_p = pearsonr(x,y)
print(f"Pearson Correlation Coefficient: {pearson_corr}")
print(f"Pearson P-Value: {pearson_p}")

#spearman correlation test
spearman_corr , spearman_p = spearmanr(x,y)
print(f"Spearman Correlation Coefficient: {spearman_corr}")
print(f"Spearman P-Value: {spearman_p}")


alpha = 0.05

def interpret_corr(corr,p,method):
    if p < alpha:
        print(f"{method},we reject the Null Hypothesis")
    else:
        print(f"{method}, we failed to reject the Null Hypothesis")

interpret_corr(pearson_corr,pearson_p,"Pearson")
interpret_corr(spearman_corr,spearman_p,"Spearman")

# %%
sns.regplot(x=x, y=y, line_kws={"color":"red"})
# Out:
# <Axes: xlabel='Treatment_Cost_USD', ylabel='Survival_Years'>

# %% [raw]
# *INFERENCE
# There is no relationship between treatmnet cost and survival years.

# %% [markdown]
# # Evaluate if higher cancer stages leads to greater treatment costs and reduced ssurvival years.

# %%
df = data.copy()

# %%
stage_order = ['Stage 0','Stage I','Stage  II','Stage III','Stage IV']

# %%
 grouped_stats = df.groupby("Cancer_Stage")[["Treatment_Cost_USD","Survival_Years"]].mean().reset_index()

# %%
Treatment Cost Vs Cancer Stage
Null  Hypothesis (h0) : The average treatment cost is the same across all cancer stages.
Alternative Hypothesis (H1) : At least one stage has a different average cost.


Survival Years vs Cancer Stage
Null Hypothesis (H0) : The average survival years are the same across all cancer stages.
Alternative Hypothesis (H1) : At least one stage has a different survival duration.

# %%
grouped_costs =[]
grouped_survival = []



for stage in stage_order:
    stage_data = df[df["Cancer_Stage"]==stage]
    cost = stage_data["Treatment_Cost_USD"]
    survival = stage_data["Survival_Years"]
    grouped_costs.append(cost)
    grouped_survival.append(survival)

# %%
len(grouped_costs)
# Out:
# 5

# %%
import numpy as np

clean_surv = np.array(grouped_survival[i])
clean_surv = clean_surv[~np.isnan(clean_surv)]

if len(clean_surv) > 2:
    surv_p = shapiro(clean_surv).pvalue
else:
    surv_p = 1   # treat small samples as normal

# %%
clean_cost = np.array(grouped_costs[i])
clean_cost = clean_cost[~np.isnan(clean_cost)]

if len(clean_cost) > 2:
    cost_p = shapiro(clean_cost).pvalue
else:
    cost_p = 1

# %%
# check for normaility
from scipy.stats import shapiro , f_oneway
normal_cost = 0
normal_survival = 0

for i in range (len(stage_order)):
    cost_p = shapiro(grouped_costs[i]).pvalue
    surv_p = shapiro(grouped_survival[i]).pvalue
    print(f" cost {cost_p} for group {i}")
    print(f" Survival {surv_p} for group {i}")
    if cost_p < 0.05:
       normal_cost+=1
    if surv_p<0.05:
        normal_survival+=1
print(cost_p)
print(surv_p)
# Out:
#  cost 1.5471821061637387e-47 for group 0
#  Survival 1.6291039522109283e-47 for group 0
#  cost 7.30652395695075e-48 for group 1
#  Survival 7.57555104625948e-48 for group 1
#  cost nan for group 2
#  Survival nan for group 2
#  cost 5.2672700330220666e-48 for group 3
#  Survival 1.3648520457944393e-47 for group 3
#  cost 1.5838640189581774e-47 for group 4
#  Survival 2.2992598289837443e-47 for group 4
# 1.5838640189581774e-47
# 2.2992598289837443e-47

# %%
print(normal_cost)
print(normal_survival)
# Out:
# 4
# 4

# %%
import numpy as np
from scipy.stats import kruskal

# remove NaNs from each group
clean_costs = [g[~np.isnan(g)] for g in grouped_costs]
clean_survival = [g[~np.isnan(g)] for g in grouped_survival]

# make sure groups are not empty
clean_costs = [g for g in clean_costs if len(g) > 0]
clean_survival = [g for g in clean_survival if len(g) > 0]

# Kruskal test (note the * to unpack the list)
kruskal_cost = kruskal(*clean_costs)
kruskal_survival = kruskal(*clean_survival)

p_cost = kruskal_cost.pvalue
p_survival = kruskal_survival.pvalue

print(p_cost, p_survival)
# Out:
# 0.7161051045284617 0.46538172857902504

# %%
from scipy.stats import kruskal

# %%
kruskal_cost = kruskal(*grouped_costs)
krukal_survival = kruskal(*grouped_survival)

p_cost =kruskal_cost.pvalue
p_survival = kruskal_survival.pvalue

# %%
p_cost
p_survival
# Out:
# np.float64(0.46538172857902504)

# %%
p_survival
# Out:
# np.float64(0.46538172857902504)

# %% [raw]
# * INFERENCE
# === Kruskal-Wallis Test : Treatment Cost Across Cancer stages ====
#
#
# P-value : 0.4254
# Conclusion: No significant difference in treatment costs among cancer stages.
#
#
# P-value: 0.4651
# Conclusion:No significant difference in survival years among cancer stages.

# %% [markdown]
# # Examine whether higher gentic risk amplifies the negative effects of smoking on cancer severity .

# %% [raw]
# Null Hypothesis(H0):
# The interaction effect between genetic risk and smoking on survival years is not significant.
# (Genetic riks doesnot amplify or alter the effect or smoking.)
#
# Alternative Hypotheis (H1):
# The interaction effect between genetic risk and smoking on survival years is  significant.
# (Genetic risk does amplify or alter the effect or smoking.)

# %%
# !pip install statsmodels
# Out:
# ...
#    ---------------------------------------- 0.0/9.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.5 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.5 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.5 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/9.5 MB 716.2 kB/s eta 0:00:13
#    -- ------------------------------------- 0.5/9.5 MB 716.2 kB/s eta 0:00:13
#    -- ------------------------------------- 0.5/9.5 MB 716.2 kB/s eta 0:00:13
#    -- ------------------------------------- 0.5/9.5 MB 716.2 kB/s eta 0:00:13
#    -- ------------------------------------- 0.5/9.5 MB 716.2 kB/s eta 0:00:13
#    -- ------------------------------------- 0.5/9.5 MB 716.2 kB/s eta 0:00:13
#    --- ------------------------------------ 0.8/9.5 MB 341.1 kB/s eta 0:00:26
#    --- ------------------------------------ 0.8/9.5 MB 341.1 kB/s eta 0:00:26
# ...

# %%
import statsmodels.formula.api as smf

#here dependent varible/response = Target_Severity_Score and independent/features = Genetic_Risk * Smoking
model = smf.ols("Target_Severity_Score ~ Genetic_Risk*Smoking",data=data).fit()

model.summary2().tables[1].loc["Genetic_Risk:Smoking"]
# Out:
# Coef.      -0.000228
# Std.Err.    0.000471
# t          -0.484187
# P>|t|       0.628255
# [0.025     -0.001150
# 0.975]      0.000694
# Name: Genetic_Risk:Smoking, dtype: float64

# %%
p_value=0.6255

# %%
Interception:
The interaction coefficient is negative but very small : -0.000228

The p-value = 0.628 , which is greater than 0.05 , so we fail to reject the Null Hypothesis

Conclusion(Statistical):
Test Used : Multiple inear Regression with interaction term

Null Hypotheis (H0) : No interaction effect betweeen genetic risk adn smoking

Alternative Hypothesis (H1) :There is an interactive effect

The interaction effect between Genetic Risk and Smoking on Target Severity Score is not statistically significant (p = 0.628 >0.05).

This means that based on your data , there is no evidence that Genetic Risk amplifies or reduces the effect of Smoking on the Target Severity Score.

In other words, smoking and genetic risk may each have independent effects(or more) , but they donot interact in a may that significantly changes the outcome.
